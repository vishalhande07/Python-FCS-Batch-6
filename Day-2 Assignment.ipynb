# %%
# Assignment DAY2
print("Hello world")
#     //THIS PRINTS THE ABOVE
print("This is a back slash \ character ")

print("Welcome python")


print("This is my the use of \"backslash\" character")
#     //ABOVE ARE USED FOR FORMATTING TEXT ALSO

print("""This is triple quotes 
Hey here is the difference
FORMATED TEXT 
can write anything
""")
#     //ABOVE CAN DISPLAY ANY THING
print('usage of single quotes')
#     // NORMAL DISPLAYING

print("usage \t of escape \n sequence")
#     //THESE ARE KNOWN AS ESCAPE SEQUENCES EITHER A TAB IS DIPLAYED OR THE TEXT WILL GO TO NEXT LINE ETC.

name = 'Vishal'
age = 18
salary = 70000
print("My name  is", name,"age is", age, "salary is", salary)
print("My name is %s age is %d salary is %d" %(name, age, salary))
#     //ABOVE ARE THE WAYS HOW DIFFERENT DATATYPES CAN BE PRINT WITHIN A STRING 

a = 100
b = 80
print(a)
print(b)
#     //SIMPLY PRINTS A AND B

print(id(a))
print(id(b))
#     //THIS PRINTS THE ADDRESS LOCATION OF THE ABOVE VARIABLES

x = y = z = 50
print(x)
print(y)
print(id(y))
#     //SAME VALUE IS GETTING ASSIGNED TO 3 DIFFERENT VARIABLES

del(x)
print(y)

#     //ABOVE DOES THE RESPECTIVES DELETE AND PRINT

# "DIFFERENT OPERATORS"
a = 10
b = 50
c= 40
print(a+b)
print(a-b)
print(a*b)
print(a/b)
print(a//b)
print(a**c)
print(a^c)
#     //THE ABOVE PRINT STATEMENTS PRINT THA ANSWER BY PERFORMING THE SPECIFIC OPERATIONS LIKE ADDITION,SUBTRACTION ETC.

x = 2
y = 5
print(x == y)
print(x > y)
print(x < y)
print(x <= y)
print(x >= y)
print(x!= y)
#      //THE ABOVE STATEMENTS WILL RETURN A BOOLEAN VALUE EITHER TRUE OR FALSE DEPENDING ON GIVEN CONDITION

x = 10
y = 50
print(x & y)#//AND OPERATOR
print(x | y)#//OR OPERATOR
print(~x)#//NEGATION
print(~y)

print(bin(x))
# //THIS PRINTS THE VALUE OF X(HERE) IN BINARY


y = 10
print(x and y)
print(x or y)


no = 10
print(10 > 9 and no >= 10)
print(10 < 9 and no >= 11)
#     //ABOVE PRINTS TRUE OR FALSE

print(15+3/2-1*15/11//20)
#     //THE FOLLOWING ANSWER WILL BE CALCULATED BY USING THE PRECENDENCE RULE

a = -1
b = 256
c = 266
print(a is b)
print(a is not c)
print(b is c)
#     //ADDRESS LOCATION IS COMPARED


str = "LETS PLAY OUT"
str1 = "PLAY"
print(str not in str1)
#     //CHECKS WHETHER STR1 IS PRESENT IN STR ..IT RETURNS A BOOLEAN VALUE

K = L = 266
print(id(K))
print(id(L))
#     //ADDRESS LOACTION WILL BE DISPLAYED BOTH HAVING DIFFERENT ADDRESS
# Out:
# Hello world
# This is a back slash \ character
# Welcome python
# This is my the use of "backslash" character
# This is triple quotes
# Hey here is the difference
# FORMATED TEXT
# can write anything
#
# usage of single quotes
# usage 	 of escape
#  sequence
# My name  is Vishal age is 18 salary is 70000
# My name is Vishal age is 18 salary is 70000
# 100
# 80
# 140708013977072
# 140708013976432
# 50
# 50
# 140708013975472
# 50
# 60
# -40
# 500
# 0.2
# 0
# 10000000000000000000000000000000000000000
# 34
# False
# False
# True
# True
# False
# True
# 2
# 58
# -11
# -51
# 0b1010
# 10
# 10
# True
# False
# 16.5
# False
# True
# False
# True
# 2185451515312
# 2185451515312
